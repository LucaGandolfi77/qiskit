# %% [markdown]
# #Qiskit 32 -
# 4 server 6 vm

# %% [markdown]
# ##Beginning settings

# %%
# !pip install Qiskit ipywidgets
# !pip install qiskit
# !pip install qiskit_optimization
# !pip install qiskit-optimization
# !pip install cplex
# !pip install ibm-quantum-widgets
# !pip install docplex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Qiskit
#   Downloading qiskit-0.39.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (7.7.1)
# Collecting qiskit-terra==0.22.4
#   Downloading qiskit_terra-0.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 22.4 MB/s eta 0:00:00
# Collecting qiskit-aer==0.11.2
#   Downloading qiskit_aer-0.11.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 30.1 MB/s eta 0:00:00
# Collecting qiskit-ibmq-provider==0.19.2
#   Downloading qiskit_ibmq_provider-0.19.2-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.4/240.4 KB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-aer==0.11.2->Qiskit) (1.21.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-aer==0.11.2->Qiskit) (1.7.3)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->Qiskit) (2.25.1)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->Qiskit) (1.24.3)
# Collecting websocket-client>=1.0.1
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 KB 2.0 MB/s eta 0:00:00
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->Qiskit) (2.8.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->Qiskit) (1.7.1)
# Collecting symengine>=0.9
#   Downloading symengine-0.9.2-cp38-cp38-manylinux2010_x86_64.whl (37.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 9.8 MB/s eta 0:00:00
# Collecting stevedore>=3.0.0
#   Downloading stevedore-4.1.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 KB 2.5 MB/s eta 0:00:00
# Collecting ply>=3.10
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->Qiskit) (0.3.6)
# Collecting tweedledum<2.0,>=1.1
#   Downloading tweedledum-1.1.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (929 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.9/929.9 KB 4.7 MB/s eta 0:00:00
# Collecting retworkx>=0.11.0
#   Downloading retworkx-0.12.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->Qiskit) (5.4.8)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (5.7.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.11.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.15.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.1.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.1)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.6.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->Qiskit) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->Qiskit) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->Qiskit) (2.10)
# Collecting ntlm-auth>=1.0.2
#   Downloading ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Collecting cryptography>=1.3
#   Downloading cryptography-39.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 33.3 MB/s eta 0:00:00
# Collecting rustworkx==0.12.1
#   Downloading rustworkx-0.12.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.7 MB/s eta 0:00:00
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 KB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.3->qiskit-terra==0.22.4->Qiskit) (1.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->Qiskit) (1.15.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.6.2)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->Qiskit) (2.21)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.11.0)
# Building wheels for collected packages: Qiskit
#   Building wheel for Qiskit (setup.py) ... done
#   Created wheel for Qiskit: filename=qiskit-0.39.5-py3-none-any.whl size=12819 sha256=29e8a05e6485f22e08d1fb4d7ec7e70c559e4550b1b92d99c69a8e84c9cb4cc9
#   Stored in directory: /root/.cache/pip/wheels/3a/51/61/70d5c6bdd5b91e78cfb59cf28ab759fac314d1c990dc93ff36
# Successfully built Qiskit
# Installing collected packages: ply, websockets, websocket-client, tweedledum, symengine, rustworkx, pbr, ntlm-auth, jedi, stevedore, retworkx, cryptography, requests-ntlm, qiskit-terra, qiskit-ibmq-provider, qiskit-aer, Qiskit
# Successfully installed Qiskit-0.39.5 cryptography-39.0.0 jedi-0.18.2 ntlm-auth-1.5.0 pbr-5.11.1 ply-3.11 qiskit-aer-0.11.2 qiskit-ibmq-provider-0.19.2 qiskit-terra-0.22.4 requests-ntlm-1.1.0 retworkx-0.12.1 rustworkx-0.12.1 stevedore-4.1.1 symengine-0.9.2 tweedledum-1.1.1 websocket-client-1.4.2 websockets-10.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: qiskit in /usr/local/lib/python3.8/dist-packages (0.39.5)
# Requirement already satisfied: qiskit-terra==0.22.4 in /usr/local/lib/python3.8/dist-packages (from qiskit) (0.22.4)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.2 in /usr/local/lib/python3.8/dist-packages (from qiskit) (0.19.2)
# Requirement already satisfied: qiskit-aer==0.11.2 in /usr/local/lib/python3.8/dist-packages (from qiskit) (0.11.2)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-aer==0.11.2->qiskit) (1.21.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-aer==0.11.2->qiskit) (1.7.3)
# Requirement already satisfied: websocket-client>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.4.2)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (10.4)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.24.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.1.0)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.8.2)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (5.4.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (4.1.1)
# Requirement already satisfied: symengine>=0.9 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (0.9.2)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (3.11)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (1.7.1)
# Requirement already satisfied: retworkx>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (0.12.1)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (1.1.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit) (0.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2.10)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.8/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (39.0.0)
# Requirement already satisfied: rustworkx==0.12.1 in /usr/local/lib/python3.8/dist-packages (from retworkx>=0.11.0->qiskit-terra==0.22.4->qiskit) (0.12.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from stevedore>=3.0.0->qiskit-terra==0.22.4->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.3->qiskit-terra==0.22.4->qiskit) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting qiskit_optimization
#   Downloading qiskit_optimization-0.4.0-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 KB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from qiskit_optimization) (1.7.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from qiskit_optimization) (1.21.6)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit_optimization) (57.4.0)
# Collecting docplex>=2.21.207
#   Downloading docplex-2.25.236.tar.gz (633 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.5/633.5 KB 21.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.8/dist-packages (from qiskit_optimization) (2.8.8)
# Requirement already satisfied: qiskit-terra>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from qiskit_optimization) (0.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from docplex>=2.21.207->qiskit_optimization) (1.15.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (1.7.1)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (3.11)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (4.1.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (0.3.6)
# Requirement already satisfied: symengine>=0.9 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (0.9.2)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (1.1.1)
# Requirement already satisfied: retworkx>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (0.12.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit_optimization) (5.4.8)
# Requirement already satisfied: rustworkx==0.12.1 in /usr/local/lib/python3.8/dist-packages (from retworkx>=0.11.0->qiskit-terra>=0.20.0->qiskit_optimization) (0.12.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from stevedore>=3.0.0->qiskit-terra>=0.20.0->qiskit_optimization) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.3->qiskit-terra>=0.20.0->qiskit_optimization) (1.2.1)
# Building wheels for collected packages: docplex
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.25.236-py3-none-any.whl size=671364 sha256=ecbf17db5a60fb688378fea6a1be634fd33c8defd752debb734a8165352ad61d
#   Stored in directory: /root/.cache/pip/wheels/b8/98/f8/22c3fe8d29be988cc4584363f494a459fb8f09c16d8e438ac7
# Successfully built docplex
# Installing collected packages: docplex, qiskit_optimization
# Successfully installed docplex-2.25.236 qiskit_optimization-0.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: qiskit-optimization in /usr/local/lib/python3.8/dist-packages (0.4.0)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-optimization) (57.4.0)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from qiskit-optimization) (1.7.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from qiskit-optimization) (1.21.6)
# Requirement already satisfied: qiskit-terra>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-optimization) (0.22.4)
# Requirement already satisfied: docplex>=2.21.207 in /usr/local/lib/python3.8/dist-packages (from qiskit-optimization) (2.25.236)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.8/dist-packages (from qiskit-optimization) (2.8.8)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from docplex>=2.21.207->qiskit-optimization) (1.15.0)
# Requirement already satisfied: symengine>=0.9 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (0.9.2)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (0.3.6)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (5.4.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (4.1.1)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (3.11)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (1.1.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (2.8.2)
# Requirement already satisfied: retworkx>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra>=0.20.0->qiskit-optimization) (0.12.1)
# Requirement already satisfied: rustworkx==0.12.1 in /usr/local/lib/python3.8/dist-packages (from retworkx>=0.11.0->qiskit-terra>=0.20.0->qiskit-optimization) (0.12.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from stevedore>=3.0.0->qiskit-terra>=0.20.0->qiskit-optimization) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.3->qiskit-terra>=0.20.0->qiskit-optimization) (1.2.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cplex
#   Downloading cplex-22.1.0.0-cp38-cp38-manylinux1_x86_64.whl (43.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: cplex
# Successfully installed cplex-22.1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ibm-quantum-widgets
#   Downloading ibm_quantum_widgets-1.0.3-py2.py3-none-any.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.4/993.4 KB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.8/dist-packages (from ibm-quantum-widgets) (7.7.1)
# Requirement already satisfied: qiskit>=0.23.5 in /usr/local/lib/python3.8/dist-packages (from ibm-quantum-widgets) (0.39.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->ibm-quantum-widgets) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->ibm-quantum-widgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->ibm-quantum-widgets) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->ibm-quantum-widgets) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->ibm-quantum-widgets) (3.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->ibm-quantum-widgets) (7.9.0)
# Requirement already satisfied: qiskit-aer==0.11.2 in /usr/local/lib/python3.8/dist-packages (from qiskit>=0.23.5->ibm-quantum-widgets) (0.11.2)
# Requirement already satisfied: qiskit-terra==0.22.4 in /usr/local/lib/python3.8/dist-packages (from qiskit>=0.23.5->ibm-quantum-widgets) (0.22.4)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.2 in /usr/local/lib/python3.8/dist-packages (from qiskit>=0.23.5->ibm-quantum-widgets) (0.19.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-aer==0.11.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.7.3)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-aer==0.11.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.21.6)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (2.25.1)
# Requirement already satisfied: websocket-client>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.4.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.24.3)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (10.4)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (2.8.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.1.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (0.3.6)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (1.7.1)
# Requirement already satisfied: symengine>=0.9 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (0.9.2)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (5.4.8)
# Requirement already satisfied: retworkx>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (0.12.1)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (1.1.1)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (4.1.1)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.8/dist-packages (from qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (3.11)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm-quantum-widgets) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->ibm-quantum-widgets) (6.1.12)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (57.4.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.18.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (5.7.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.8.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (1.8.0)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (5.6.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (5.1.2)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (2.11.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (23.2.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (5.7.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (2022.12.7)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.8/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (39.0.0)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.5.0)
# Requirement already satisfied: rustworkx==0.12.1 in /usr/local/lib/python3.8/dist-packages (from retworkx>=0.11.0->qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (0.12.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from stevedore>=3.0.0->qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.3->qiskit-terra==0.22.4->qiskit>=0.23.5->ibm-quantum-widgets) (1.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.7.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (1.15.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (2.6.2)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (4.3.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.23.5->ibm-quantum-widgets) (2.21)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (5.10.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->ibm-quantum-widgets) (3.11.0)
# Installing collected packages: ibm-quantum-widgets
# Successfully installed ibm-quantum-widgets-1.0.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: docplex in /usr/local/lib/python3.8/dist-packages (2.25.236)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from docplex) (1.15.0)

# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
#provider = IBMQ.load_account()

# %%
import time
from typing import List, Optional, Any
import numpy as np
import matplotlib.pyplot as plt

from docplex.mp.model import Model

from qiskit import BasicAer
from qiskit.algorithms import QAOA, NumPyMinimumEigensolver
from qiskit_optimization.algorithms import CobylaOptimizer, MinimumEigenOptimizer
from qiskit_optimization.problems import QuadraticProgram
from qiskit_optimization.algorithms.admm_optimizer import ADMMParameters, ADMMOptimizer
from qiskit_optimization.translators import from_docplex_mp

from qiskit.utils.algorithm_globals import algorithm_globals
algorithm_globals.massive=True

# If CPLEX is installed, you can uncomment this line to import the CplexOptimizer.
# CPLEX can be used in this tutorial to solve the convex continuous problem,
# but also as a reference to solve the QUBO, or even the full problem.
#
# from qiskit.optimization.algorithms import CplexOptimizer

# %%
# define COBYLA optimizer to handle convex continuous problems.
cobyla = CobylaOptimizer()

# define QAOA via the minimum eigen optimizer
qaoa = MinimumEigenOptimizer(QAOA(quantum_instance=BasicAer.get_backend("statevector_simulator")))

# exact QUBO solver as classical benchmark
exact = MinimumEigenOptimizer(NumPyMinimumEigensolver())  # to solve QUBOs

# in case CPLEX is installed it can also be used for the convex problems, the QUBO,
# or as a benchmark for the full problem.
#
# cplex = CplexOptimizer()

# %% [markdown]
# ##Problem definition

# %%
# construct model using docplex
mdl = Model("ex25")

#server = M = 4 = i = i0, i1, i2, i3
#virtual machine = N = 6 = j = j0, j1, j2, j3, j4, j5
#all servers have the same idle and dynamic power consumption
#all servers have the same maximum cpu capacity

si0 = mdl.binary_var(name="si0")
si1 = mdl.binary_var(name="si1")
si2 = mdl.binary_var(name="si2")
si3 = mdl.binary_var(name="si3")

vj0i0 = mdl.continuous_var(name="vj0i0")
vj1i0 = mdl.continuous_var(name="vj1i0")
vj2i0 = mdl.continuous_var(name="vj2i0")
vj3i0 = mdl.continuous_var(name="vj3i0")
vj4i0 = mdl.continuous_var(name="vj4i0")
vj5i0 = mdl.continuous_var(name="vj5i0")

vj0i1 = mdl.continuous_var(name="vj0i1")
vj1i1 = mdl.continuous_var(name="vj1i1")
vj2i1 = mdl.continuous_var(name="vj2i1")
vj3i1 = mdl.continuous_var(name="vj3i1")
vj4i1 = mdl.continuous_var(name="vj4i1")
vj5i1 = mdl.continuous_var(name="vj5i1")

vj0i2 = mdl.continuous_var(name="vj0i2")
vj1i2 = mdl.continuous_var(name="vj1i2")
vj2i2 = mdl.continuous_var(name="vj2i2")
vj3i2 = mdl.continuous_var(name="vj3i2")
vj4i2 = mdl.continuous_var(name="vj4i2")
vj5i2 = mdl.continuous_var(name="vj5i2")

vj0i3 = mdl.continuous_var(name="vj0i3")
vj1i3 = mdl.continuous_var(name="vj1i3")
vj2i3 = mdl.continuous_var(name="vj2i3")
vj3i3 = mdl.continuous_var(name="vj3i3")
vj4i3 = mdl.continuous_var(name="vj4i3")
vj5i3 = mdl.continuous_var(name="vj5i3")

pi = 10
pd = 5

ci0 = 100
ci1 = 130
ci2 = 100
ci3 = 70

uj0 = mdl.continuous_var(name="uj0")
uj1 = mdl.continuous_var(name="uj1")
uj2 = mdl.continuous_var(name="uj2")
uj3 = mdl.continuous_var(name="uj3")
uj4 = mdl.continuous_var(name="uj4")
uj5 = mdl.continuous_var(name="uj5")

sum0 = (vj0i0+vj1i0+vj2i0+vj3i0+vj4i0+vj5i0)
sum1 = (vj0i1+vj1i1+vj2i1+vj3i1+vj4i1+vj5i1)
sum2 = (vj0i2+vj1i2+vj2i2+vj3i2+vj4i2+vj5i2)
sum3 = (vj0i3+vj1i3+vj2i3+vj3i3+vj4i3+vj5i3)

mdl.minimize(pi*si0+pd*(sum0)+pi*si1+pd*uj1*(sum1)+pi*si2+pd*(sum2)+pi*si3+pd*(sum3))

mdl.add_constraint((vj0i0+vj1i0+vj2i0+vj3i0+vj4i0+vj5i0) >= ci0-5, "cons5")
mdl.add_constraint((vj0i1+vj1i1+vj2i1+vj3i1+vj4i1+vj5i1) >= ci1-5, "cons6")
mdl.add_constraint((vj0i2+vj1i2+vj2i2+vj3i2+vj4i2+vj5i2) >= ci2-5, "cons7")
mdl.add_constraint((vj0i3+vj1i3+vj2i3+vj3i3+vj4i3+vj5i3) >= ci3-5, "cons8")

mdl.add_constraint((vj0i0+vj1i0+vj2i0+vj3i0+vj4i0+vj5i0) <= ci0,"cons10")
mdl.add_constraint((vj0i1+vj1i1+vj2i1+vj3i1+vj4i1+vj5i1) <= ci1, "cons11")
mdl.add_constraint((vj0i2+vj1i2+vj2i2+vj3i2+vj4i2+vj5i2) <= ci2, "cons12")
mdl.add_constraint((vj0i3+vj1i3+vj2i3+vj3i3+vj4i3+vj5i3) <= ci3, "cons13")

mdl.add_constraint((si0) >= 1, "cons14")
mdl.add_constraint((si1) >= 1, "cons15")
mdl.add_constraint((si2) >= 1, "cons16")
mdl.add_constraint((si3) >= 1, "cons17")

#mdl.add_constraint((vj0i0+vj1i0+vj2i0+vj3i0+vj4i0+vj5i0) >= 0.9, "cons5")
#mdl.add_constraint((vj0i1+vj1i1+vj2i1+vj3i1+vj4i1+vj5i1) >= 0.9, "cons6")
#mdl.add_constraint((vj0i2+vj1i2+vj2i2+vj3i2+vj4i2+vj5i2) >= 0.9, "cons7")
#mdl.add_constraint((vj0i3+vj1i3+vj2i3+vj3i3+vj4i3+vj5i3) >= 0.9, "cons8")

#mdl.add_constraint((vj0i0+vj1i0+vj2i0+vj3i0+vj4i0+vj5i0) <= 0.99,"cons10")
#mdl.add_constraint((vj0i1+vj1i1+vj2i1+vj3i1+vj4i1+vj5i1) <= 0.99, "cons11")
#mdl.add_constraint((vj0i2+vj1i2+vj2i2+vj3i2+vj4i2+vj5i2) <= 0.99, "cons12")
#mdl.add_constraint((vj0i3+vj1i3+vj2i3+vj3i3+vj4i3+vj5i3) <= 0.99, "cons13")
# Out:
# docplex.mp.LinearConstraint[cons17](si3,GE,1)

# %% [markdown]
# ![Immagine 2022-06-27 075042.png](data:image/png;base64,...)

# %% [markdown]
# ![Immagine 2022-06-27 081850.png](data:image/png;base64,...)

# %%
# load quadratic program from docplex model
qp = from_docplex_mp(mdl)
print(qp.export_as_lp_string())
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: ex25
#
# Minimize
#  obj: 10 si0 + 10 si1 + 10 si2 + 10 si3 + 5 vj0i0 + 5 vj1i0 + 5 vj2i0 + 5 vj3i0
#       + 5 vj4i0 + 5 vj5i0 + 5 vj0i2 + 5 vj1i2 + 5 vj2i2 + 5 vj3i2 + 5 vj4i2
#       + 5 vj5i2 + 5 vj0i3 + 5 vj1i3 + 5 vj2i3 + 5 vj3i3 + 5 vj4i3 + 5 vj5i3 + [
#       10 vj0i1*uj1 + 10 vj1i1*uj1 + 10 vj2i1*uj1 + 10 vj3i1*uj1 + 10 vj4i1*uj1
#       + 10 vj5i1*uj1 ]/2
# Subject To
#  cons5: vj0i0 + vj1i0 + vj2i0 + vj3i0 + vj4i0 + vj5i0 >= 95
#  cons6: vj0i1 + vj1i1 + vj2i1 + vj3i1 + vj4i1 + vj5i1 >= 125
#  cons7: vj0i2 + vj1i2 + vj2i2 + vj3i2 + vj4i2 + vj5i2 >= 95
#  cons8: vj0i3 + vj1i3 + vj2i3 + vj3i3 + vj4i3 + vj5i3 >= 65
#  cons10: vj0i0 + vj1i0 + vj2i0 + vj3i0 + vj4i0 + vj5i0 <= 100
#  cons11: vj0i1 + vj1i1 + vj2i1 + vj3i1 + vj4i1 + vj5i1 <= 130
#  cons12: vj0i2 + vj1i2 + vj2i2 + vj3i2 + vj4i2 + vj5i2 <= 100
#  cons13: vj0i3 + vj1i3 + vj2i3 + vj3i3 + vj4i3 + vj5i3 <= 70
#  cons14: si0 >= 1
#  cons15: si1 >= 1
#  cons16: si2 >= 1
#  cons17: si3 >= 1
#
# Bounds
#  0 <= si0 <= 1
#  0 <= si1 <= 1
#  0 <= si2 <= 1
#  0 <= si3 <= 1
#
# Binaries
#  si0 si1 si2 si3
# End

# %% [markdown]
# ##Classical solution

# %%
admm_params = ADMMParameters(
                            rho_initial=1001,
                            beta=1000,
                            factor_c=900,
                            maxiter=100,
                            three_block=True, tol=1.e-6
                        )

# %%
# define QUBO optimizer
qubo_optimizer = exact
# qubo_optimizer = cplex  # uncomment to use CPLEX instead

# define classical optimizer
convex_optimizer = cobyla
# convex_optimizer = cplex  # uncomment to use CPLEX instead

# initialize ADMM with classical QUBO and convex optimizer
admm = ADMMOptimizer(params=admm_params,
                     qubo_optimizer=qubo_optimizer,
                     continuous_optimizer=convex_optimizer,
                    )

# %%
# run ADMM to solve problem
#%tb
# %timeit
result = admm.solve(qp)

# %%
print(result.prettyprint())
# Out:
# objective function value: 1314.9999999999998
# variable values: si0=1.0, si1=1.0, si2=1.0, si3=1.0, vj0i0=15.764952166327976, vj1i0=15.787666589350472, vj2i0=15.831553929312529, vj3i0=15.803581704236462, vj4i0=15.990203149292844, vj5i0=15.822042461479715, vj0i1=20.747838502505804, vj1i1=22.230305421558022, vj2i1=20.46492286350065, vj3i1=20.464626560470496, vj4i1=20.464176857165594, vj5i1=20.761802167688696, vj0i2=16.01225745166214, vj1i2=16.10029495618164, vj2i2=16.04313058255844, vj3i2=15.735501733439675, vj4i2=16.078558721271456, vj5i2=15.030256554886641, vj0i3=11.859593339642668, vj1i3=10.414454355270927, vj2i3=10.40743825670949, vj3i3=10.410025399356499, vj4i3=10.4094659010195, vj5i3=11.499022748000918, uj0=0.0015043955222420068, uj1=7.614592258137198e-21, uj2=0.042691362714774944, uj3=1.0672641896054358e-05, uj4=0.001870872131649626, uj5=0.00024252182237460363
# status: SUCCESS

# %%
print(f"vj0i0=15.833203823269944, vj1i0=15.833356482350474, vj2i0=15.83351528067469, vj3i0=15.833346959064396, vj4i0=15.83327016528088, vj5i0=15.833307289359617, vj0i1=20.981811860339693, vj1i1=21.431644805734642, vj2i1=20.673826629800644, vj3i1=20.673750927740297, vj4i1=20.67375718520671, vj5i1=20.673815533046607, vj0i2=15.833337325309735, vj1i2=15.833368241568234, vj2i2=15.83329609545665, vj3i2=15.833280092698791, vj4i2=15.833284821567016, vj5i2=15.833433423399574, vj0i3=10.863487940977873, vj1i3=10.838852457227105, vj2i3=10.838880490927862, vj3i3=10.916712504795234, vj4i3=10.917150104637637, vj5i3=10.624916501434289, uj0=3.043120757378878e-07, uj1=1.4923742233541295e-22, uj2=0.9998022337171757, uj3=0.9998691327097831, uj4=9.282309221937615e-05, uj5=5.651087477267203e-22")
# Out:
# vj0i0=15.833203823269944, vj1i0=15.833356482350474, vj2i0=15.83351528067469, vj3i0=15.833346959064396, vj4i0=15.83327016528088, vj5i0=15.833307289359617, vj0i1=20.981811860339693, vj1i1=21.431644805734642, vj2i1=20.673826629800644, vj3i1=20.673750927740297, vj4i1=20.67375718520671, vj5i1=20.673815533046607, vj0i2=15.833337325309735, vj1i2=15.833368241568234, vj2i2=15.83329609545665, vj3i2=15.833280092698791, vj4i2=15.833284821567016, vj5i2=15.833433423399574, vj0i3=10.863487940977873, vj1i3=10.838852457227105, vj2i3=10.838880490927862, vj3i3=10.916712504795234, vj4i3=10.917150104637637, vj5i3=10.624916501434289, uj0=3.043120757378878e-07, uj1=1.4923742233541295e-22, uj2=0.9998022337171757, uj3=0.9998691327097831, uj4=9.282309221937615e-05, uj5=5.651087477267203e-22

# %%
vj0i0_sol=15.833203823269944
vj1i0_sol=15.833356482350474
vj2i0_sol=15.83351528067469
vj3i0_sol=15.833346959064396
vj4i0_sol=15.83327016528088
vj5i0_sol=15.833307289359617
vj0i1_sol=20.981811860339693
vj1i1_sol=21.431644805734642
vj2i1_sol=20.673826629800644
vj3i1_sol=20.673750927740297
vj4i1_sol=20.67375718520671
vj5i1_sol=20.673815533046607
vj0i2_sol=15.833337325309735
vj1i2_sol=15.833368241568234
vj2i2_sol=15.83329609545665
vj3i2_sol=15.833280092698791
vj4i2_sol=15.833284821567016
vj5i2_sol=15.833433423399574
vj0i3_sol=10.863487940977873
vj1i3_sol=10.838852457227105
vj2i3_sol=10.838880490927862
vj3i3_sol=10.916712504795234
vj4i3_sol=10.917150104637637
vj5i3_sol=10.624916501434289

vi0_sol=vj0i0_sol+vj1i0_sol+vj2i0_sol+vj3i0_sol+vj4i0_sol+vj5i0_sol
vi1_sol=vj0i1_sol+vj1i1_sol+vj2i1_sol+vj3i1_sol+vj4i1_sol+vj5i1_sol
vi2_sol=vj0i2_sol+vj1i2_sol+vj2i2_sol+vj3i2_sol+vj4i2_sol+vj5i2_sol
vi3_sol=vj0i3_sol+vj1i3_sol+vj2i2_sol+vj3i3_sol+vj4i3_sol+vj5i3_sol

vj0_sol=vj0i0_sol+vj0i1_sol+vj0i2_sol+vj0i3_sol
vj1_sol=vj1i0_sol+vj1i1_sol+vj1i2_sol+vj1i3_sol
vj2_sol=vj2i0_sol+vj2i1_sol+vj2i2_sol+vj2i3_sol
vj3_sol=vj3i0_sol+vj3i1_sol+vj3i2_sol+vj3i3_sol
vj4_sol=vj4i0_sol+vj4i1_sol+vj4i2_sol+vj4i3_sol
vj5_sol=vj5i0_sol+vj5i1_sol+vj5i2_sol+vj5i3_sol

print("vi0_sol = ",vi0_sol,"\nvi1_sol = ",vi1_sol,"\nvi2_sol = ",vi2_sol,"\nvi3_sol = ",vi3_sol)
print("vitot = ",vi0_sol+vi0_sol+vi1_sol+vi2_sol)
print("vj0_sol = ",vj0_sol,"\nvj1_sol = ",vj1_sol,"\nvj2_sol = ",vj2_sol,"\nvj3_sol = ",vj3_sol,"\nvj4_sol = ",vj4_sol,"\nvj5_sol = ",vj5_sol)
print("vjtot = ",vj0_sol+vj1_sol+vj2_sol+vj3_sol+vj4_sol+vj5_sol)
# Out:
# vi0_sol =  95.0
# vi1_sol =  125.1086069418686
# vi2_sol =  95.0
# vi3_sol =  69.99441560452878
# vitot =  410.10860694186863
# vj0_sol =  63.51184094989725
# vj1_sol =  63.93722198688046
# vj2_sol =  63.17951849685984
# vj3_sol =  63.25709048429872
# vj4_sol =  63.257462276692245
# vj5_sol =  62.965472747240085
# vjtot =  380.1086069418686

# %%
print("x={:}".format(result.x))
print("fval={:.7f}".format(result.fval))
print("x={:}".format(result.state.residuals))
# Out:
# x=[1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.57649522e+01 1.57876666e+01 1.58315539e+01 1.58035817e+01
#  1.59902031e+01 1.58220425e+01 2.07478385e+01 2.22303054e+01
#  2.04649229e+01 2.04646266e+01 2.04641769e+01 2.07618022e+01
#  1.60122575e+01 1.61002950e+01 1.60431306e+01 1.57355017e+01
#  1.60785587e+01 1.50302566e+01 1.18595933e+01 1.04144544e+01
#  1.04074383e+01 1.04100254e+01 1.04094659e+01 1.14990227e+01
#  1.50439552e-03 7.61459226e-21 4.26913627e-02 1.06726419e-05
#  1.87087213e-03 2.42521822e-04]
# fval=1315.0000000
# x=[0.9995020175068178, 0.4762563130294102, 0.2152444149186244, 0.09234047726172963, 0.03736255126447233, 0.014346124137683621, 0.0053073974003256495, 0.0016551384034194443, 0.000600319004287452, 0.00020947608351784113, 0.00016501314466924974, 0.00012136802365061648, 0.0001477079747400921, 9.99999999989119e-05, 0.0001422089694027682, 0.00012097379921432692, 0.00012389034892476626, 0.00016886064054580564, 0.00011487264333044734, 0.00012199960848218998, 0.00015600805171563827, 0.00011645580047077739, 0.00012438647788936524, 0.0001577556212079315, 0.00012361234666078948, 0.00011326334613342916, 0.00017303966467791464, 0.00019409230838631124, 0.0001528870759787827, 0.00010000000000008331, 9.999999999997569e-05, 0.00011270535920881811, 0.00015992744910611875, 0.00015503078551898952, 0.00012140741812958747, 0.00019013702116964, 0.0001583398466921702, 0.00011774043185472498, 0.00011665322003629734, 0.0001431852874558265, 0.00019872399250958064, 0.00021580306972480333, 0.0001616912201499825, 9.999999999987073e-05, 0.00015652475426519087, 0.00012470138234811165, 0.00010000000000010654, 0.00016953283630798837, 0.0001334313187375691, 0.00015904876673762712, 0.00010000000000018576, 9.999999999990956e-05, 0.00015989154872464545, 0.00014725544630924813, 0.00016682076695168158, 0.00015143846771028673, 0.00015359708449830592, 0.00014287426278054545, 0.00013346031080701246, 0.0001738265532612125, 0.00019378767444269172, 0.0001118381121517076, 0.00015069524035914118, 0.00012124581249610266, 0.0001526736216452581, 0.0001000000000000806, 0.00012212228191837795, 0.00017579589959478955, 0.00016490827057374599, 9.99999999999409e-05, 9.999999999809227e-05, 0.00011376719389576444, 0.00012318576437365562, 0.00016182977015583526, 0.00015478890868513514, 9.999999999999999e-05, 9.999999999998614e-05, 0.00011590656017417222, 0.0001, 0.00015941467794146087, 0.00019618631734634004, 0.0001619329606218521, 0.0001435545427814883, 0.00011429302237185734, 9.999999999985411e-05, 0.0001000000000000268, 9.999999999997248e-05, 0.0001000000000000084, 0.00010000000000000383, 0.00015838623376477652, 0.00016068678198402126, 0.00013015955723904578, 0.0001583089645540516, 0.0001536785465387537, 9.99999999999316e-05, 0.00010000000000004612, 0.00017445964060249647, 0.00010000000000121701, 9.999999999984106e-05, 0.00012437302606551959]

# %%
plt.plot(result.state.residuals)
plt.xlabel("Iterations")
plt.ylabel("Residuals")
plt.show()

# %%
lista = []
lista = result.state.residuals

# %%
plt.plot(result.x)
plt.xlabel("Iterations")
plt.ylabel("Results")
plt.show()

# %%
#import matplotlib.pyplot as plt
#
#fig, ax = plt.subplots()
#
#f = [result.x]
#c = [40, 100, 30, 55]
#
#ax.bar(f, c,)
#
#ax.set_ylabel("Residuals")
#ax.set_title("Results")
#
#
#plt.show()

# %%
result
# Out:
# <ADMMOptimizationResult: fval=1314.9999999999998, si0=1.0, si1=1.0, si2=1.0, si3=1.0, vj0i0=15.764952166327976, vj1i0=15.787666589350472, vj2i0=15.831553929312529, vj3i0=15.803581704236462, vj4i0=15.990203149292844, vj5i0=15.822042461479715, vj0i1=20.747838502505804, vj1i1=22.230305421558022, vj2i1=20.46492286350065, vj3i1=20.464626560470496, vj4i1=20.464176857165594, vj5i1=20.761802167688696, vj0i2=16.01225745166214, vj1i2=16.10029495618164, vj2i2=16.04313058255844, vj3i2=15.735501733439675, vj4i2=16.078558721271456, vj5i2=15.030256554886641, vj0i3=11.859593339642668, vj1i3=10.414454355270927, vj2i3=10.40743825670949, vj3i3=10.410025399356499, vj4i3=10.4094659010195, vj5i3=11.499022748000918, uj0=0.0015043955222420068, uj1=7.614592258137198e-21, uj2=0.042691362714774944, uj3=1.0672641896054358e-05, uj4=0.001870872131649626, uj5=0.00024252182237460363, status=SUCCESS>

# %% [markdown]
# <qiskit_optimization.algorithms.admm_optimizer.ADMMState at 0x7f139d9c9a10>

# %% [markdown]
# ##Quantum solution

# %%
# define QUBO optimizer
qubo_optimizer = qaoa

# define classical optimizer
convex_optimizer = cobyla
# convex_optimizer = cplex  # uncomment to use CPLEX instead

# initialize ADMM with quantum QUBO optimizer and classical convex optimizer
admm_q = ADMMOptimizer(
    params=admm_params, qubo_optimizer=qubo_optimizer, continuous_optimizer=convex_optimizer
)

# %%
# run ADMM to solve problem
result_q = admm_q.solve(qp)

# %%
print(result_q.prettyprint())
# Out:
# objective function value: 1314.9999999999998
# variable values: si0=1.0, si1=1.0, si2=1.0, si3=1.0, vj0i0=15.764952166327976, vj1i0=15.787666589350472, vj2i0=15.831553929312529, vj3i0=15.803581704236462, vj4i0=15.990203149292844, vj5i0=15.822042461479715, vj0i1=20.747838502505804, vj1i1=22.230305421558022, vj2i1=20.46492286350065, vj3i1=20.464626560470496, vj4i1=20.464176857165594, vj5i1=20.761802167688696, vj0i2=16.01225745166214, vj1i2=16.10029495618164, vj2i2=16.04313058255844, vj3i2=15.735501733439675, vj4i2=16.078558721271456, vj5i2=15.030256554886641, vj0i3=11.859593339642668, vj1i3=10.414454355270927, vj2i3=10.40743825670949, vj3i3=10.410025399356499, vj4i3=10.4094659010195, vj5i3=11.499022748000918, uj0=0.0015043955222420068, uj1=7.614592258137198e-21, uj2=0.042691362714774944, uj3=1.0672641896054358e-05, uj4=0.001870872131649626, uj5=0.00024252182237460363
# status: SUCCESS

# %%
vj0i0_solq=15.833203823269944
vj1i0_solq=15.833356482350474
vj2i0_solq=15.83351528067469
vj3i0_solq=15.833346959064396
vj4i0_solq=15.83327016528088
vj5i0_solq=15.833307289359617
vj0i1_solq=20.981811860339693
vj1i1_solq=21.431644805734642
vj2i1_solq=20.673826629800644
vj3i1_solq=20.673750927740297
vj4i1_solq=20.67375718520671
vj5i1_solq=20.673815533046607
vj0i2_solq=15.833337325309735
vj1i2_solq=15.833368241568234
vj2i2_solq=15.83329609545665
vj3i2_solq=15.833280092698791
vj4i2_solq=15.833284821567016
vj5i2_solq=15.833433423399574
vj0i3_solq=10.863487940977873
vj1i3_solq=10.838852457227105
vj2i3_solq=10.838880490927862
vj3i3_solq=10.916712504795234
vj4i3_solq=10.917150104637637
vj5i3_solq=10.624916501434289

vi0_solq=vj0i0_solq+vj1i0_solq+vj2i0_solq+vj3i0_solq+vj4i0_solq+vj5i0_solq
vi1_solq=vj0i1_solq+vj1i1_solq+vj2i1_solq+vj3i1_solq+vj4i1_solq+vj5i1_solq
vi2_solq=vj0i2_solq+vj1i2_solq+vj2i2_solq+vj3i2_solq+vj4i2_solq+vj5i2_solq
vi3_solq=vj0i3_solq+vj1i3_solq+vj2i2_solq+vj3i3_solq+vj4i3_solq+vj5i3_solq

vj0_solq=vj0i0_solq+vj0i1_solq+vj0i2_solq+vj0i3_solq
vj1_solq=vj1i0_solq+vj1i1_solq+vj1i2_solq+vj1i3_solq
vj2_solq=vj2i0_solq+vj2i1_solq+vj2i2_solq+vj2i3_solq
vj3_solq=vj3i0_solq+vj3i1_solq+vj3i2_solq+vj3i3_solq
vj4_solq=vj4i0_solq+vj4i1_solq+vj4i2_solq+vj4i3_solq
vj5_solq=vj5i0_solq+vj5i1_solq+vj5i2_solq+vj5i3_solq

print("vi0_sol = ",vi0_solq,"\nvi1_sol = ",vi1_solq,"\nvi2_sol = ",vi2_solq,"\nvi3_sol = ",vi3_solq)
print("vitot = ",vi0_solq+vi0_solq+vi1_solq+vi2_solq)
print("vj0_sol = ",vj0_solq,"\nvj1_sol = ",vj1_solq,"\nvj2_sol = ",vj2_solq,"\nvj3_sol = ",vj3_solq,"\nvj4_sol = ",vj4_solq,"\nvj5_sol = ",vj5_solq)
print("vjtot = ",vj0_solq+vj1_solq+vj2_solq+vj3_solq+vj4_solq+vj5_solq)
# Out:
# vi0_sol =  95.0
# vi1_sol =  125.1086069418686
# vi2_sol =  95.0
# vi3_sol =  69.99441560452878
# vitot =  410.10860694186863
# vj0_sol =  63.51184094989725
# vj1_sol =  63.93722198688046
# vj2_sol =  63.17951849685984
# vj3_sol =  63.25709048429872
# vj4_sol =  63.257462276692245
# vj5_sol =  62.965472747240085
# vjtot =  380.1086069418686

# %%
plt.clf()
plt.plot(result_q.state.residuals)
plt.xlabel("Iterations")
plt.ylabel("Residuals")
plt.show()

# %%
plt.plot(result_q.x)
plt.xlabel("Iterations")
plt.ylabel("Results")
plt.show()

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# %qiskit_copyright
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.22.4</td></tr><tr><td><code>qiskit-aer</code></td><td>0.11.2</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.19.2</td></tr><tr><td><code>qiskit</code></td><td>0.39.5</td></tr><tr><td><code>qiskit-optimization</code></td><td>0.4.0</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.8.16</td></tr><tr><td>Python compiler</td><td>GCC 7.5.0</td></tr><tr><td>Python build</td><td>default, Dec  7 2022 01:12:13</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>1</td></tr><tr><td>Memory (Gb)</td><td>12.681198120117188</td></tr><tr><td colspan='2'>Wed Jan 25 15:14:17 2023 UTC</td></tr></table>
# <div style='width: 100%; background-color:#d5d9e0;padding-left: 10px; padding-bottom: 10px; padding-right: 10px; padding-top: 5px'><h3>This code is a part of Qiskit</h3><p>&copy; Copyright IBM 2017, 2023.</p><p>This code is licensed under the Apache License, Version 2.0. You may<br>obtain a copy of this license in the LICENSE.txt file in the root directory<br> of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.<p>Any modifications or derivative works of this code must retain this<br>copyright notice, and modified files need to carry a notice indicating<br>that they have been altered from the originals.</p></div>
